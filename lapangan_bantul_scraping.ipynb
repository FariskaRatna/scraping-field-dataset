# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install googlemaps
import googlemaps
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: googlemaps in c:\users\user\appdata\roaming\python\python311\site-packages (4.10.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from googlemaps) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.20.0->googlemaps) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
bantul_df = pd.read_csv("Bantul.csv")
bantul_df
# Out:
#         kecamatan  luas_wilayah_(km2)
# 0       Srandakan               18.32
# 1          Sanden               23.16
# 2          Kretek               26.77
# 3         Pundong               23.68
# 4   Bambanglipuro               22.70
# 5          Pandak               24.30
# 6          Bantul               21.95
# 7           Jetis               24.47
# 8         Imogiri               54.49
# 9          Dlingo               55.87
# 10         Pleret               22.97
# 11       Piyungan               32.54
# 12    Banguntapan               28.48
# 13          Sewon               27.16
# 14        Kasihan               32.38
# 15       Pajangan               33.25
# 16         Sedayu               34.36

# %% [markdown]
# ### Scraping Lapangan

# %%
bantul_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kecamatan           17 non-null     object
#  1   luas_wilayah_(km2)  17 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 404.0+ bytes

# %%
# bantul_df['luas_wilayah_(km2)'] = bantul_df['luas_wilayah_(km2)'].apply(lambda x: float(x.replace(',', '.')))

# %%
def radius(luas):
    return np.sqrt((luas*1000000/np.pi))

# %%
map_client = googlemaps.Client("AIzaSyD4NxoIzL7sZcUB-ZMrGXerlzedHm1YcZA")

# %%
location = pd.DataFrame()

# %%
def place_location(df, nama_kecamatan, nama_kabupaten):
    location_name = f"{nama_kecamatan} {nama_kabupaten}"
    response = map_client.places(query = location_name)
    results = response.get('results')
    if results:
      print(results[0]['geometry']['location'])
      df = df.append(results[0]['geometry']['location'], ignore_index = True)
    else:
      print("No results found for query: ", location_name)

    return df

# %%
for index, row in bantul_df.iterrows():
    location = place_location(location, row['kecamatan'], 'Kabupaten Bantul Yogyakarta')
# Out:
# {'lat': -7.938720999999999, 'lng': 110.253601}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.9904148, 'lng': 110.2663226}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.9918683, 'lng': 110.3003782}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.9749966, 'lng': 110.3335415}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.954890000000001, 'lng': 110.2928505}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8975532, 'lng': 110.2981682}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8748176, 'lng': 110.3255365}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.913659999999999, 'lng': 110.3728136}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.920103999999999, 'lng': 110.385101}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.925561099999999, 'lng': 110.4686765}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.870035799999999, 'lng': 110.3909634}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.838150199999999, 'lng': 110.4760537}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.811851099999999, 'lng': 110.4091104}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.835594499999999, 'lng': 110.3656196}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8221984, 'lng': 110.3282052}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8799815, 'lng': 110.3127619}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8189313, 'lng': 110.2568346}
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)

# %%
bantul_df["lat"] = location["lat"]
bantul_df["lng"] = location["lng"]

# %%
place_list = pd.DataFrame()

# %%
def search_places (location, search_string, distance, place_list):
    response = map_client.places_nearby(
        location = location,
        keyword = search_string,
        radius = distance,
    )
    results = response.get('results')
    place_list = place_list.append(results)

    return place_list

# %%
lapangan_df = pd.DataFrame()

# %%
for index, row in bantul_df.iterrows() :
    loc = (location.iloc[index]['lat'], location.iloc[index]['lng'])
    dist = radius(bantul_df.iloc[index]['luas_wilayah_(km2)'])
    location_name = f"{bantul_df.iloc[index]['kecamatan']} Kabupaten Bantul Yogyakarta"
    lapangan_df = search_places(loc, "Lapangan", dist, lapangan_df)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_14248\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)

# %% [markdown]
# ### Hasil Scraping Lapangan

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.934011099999998, 'lng'...
# 1      OPERATIONAL  {'location': {'lat': -7.928185699999999, 'lng'...
# 2      OPERATIONAL  {'location': {'lat': -7.960124999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.9249978, 'lng': 110.24...
# 4      OPERATIONAL  {'location': {'lat': -7.937201, 'lng': 110.234...
# ..             ...                                                ...
# 15     OPERATIONAL  {'location': {'lat': -7.8275029, 'lng': 110.26...
# 16     OPERATIONAL  {'location': {'lat': -7.847789, 'lng': 110.270...
# 17     OPERATIONAL  {'location': {'lat': -7.800039399999999, 'lng'...
# 18     OPERATIONAL  {'location': {'lat': -7.816321899999999, 'lng'...
# 19     OPERATIONAL  {'location': {'lat': -7.820927, 'lng': 110.260...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                ...                   ...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                   name        opening_hours  \
# 0                   Lapangan Tegalombo   {'open_now': True}
# 1                       Lapangan Bendo   {'open_now': True}
# 2                   Lapangan PONCOSARI   {'open_now': True}
# 3               Sidorejo Village Field   {'open_now': True}
# 4                        Klampok Field   {'open_now': True}
# ..                                 ...                  ...
# 15                  LAPANGAN BOLA VOLI  {'open_now': False}
# 16              Lapangan Voli Sidodadi   {'open_now': True}
# 17                        Ares stadium                  NaN
# 18     Lapangan sepak bola banguncipto                  NaN
# 19  Lapangan Voli Krida Taruna Ngentak                  NaN
#
#                                                photos  \
# 0   [{'height': 2400, 'html_attributions': ['<a hr...
# 1   [{'height': 1840, 'html_attributions': ['<a hr...
# 2   [{'height': 2448, 'html_attributions': ['<a hr...
# 3   [{'height': 1080, 'html_attributions': ['<a hr...
# 4   [{'height': 3120, 'html_attributions': ['<a hr...
# ..                                                ...
# 15  [{'height': 2560, 'html_attributions': ['<a hr...
# 16  [{'height': 3000, 'html_attributions': ['<a hr...
# 17  [{'height': 1280, 'html_attributions': ['<a hr...
# 18  [{'height': 1152, 'html_attributions': ['<a hr...
# 19  [{'height': 3456, 'html_attributions': ['<a hr...
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJWVEQD2X-ei4RNu5orBGMxUU     4.5  ChIJWVEQD2X-ei4RNu5orBGMxUU  GOOGLE
# 1   ChIJIzJXtGP-ei4R_h2NiX8MN50     4.3  ChIJIzJXtGP-ei4R_h2NiX8MN50  GOOGLE
# 2   ChIJWXkJCQf-ei4R9nctc1bI0e8     4.3  ChIJWXkJCQf-ei4R9nctc1bI0e8  GOOGLE
# 3   ChIJgXS1d4f-ei4Rq5ispU3jGdk     4.4  ChIJgXS1d4f-ei4Rq5ispU3jGdk  GOOGLE
# 4   ChIJjxzVaNj9ei4RkUlK2RaW76w     4.2  ChIJjxzVaNj9ei4RkUlK2RaW76w  GOOGLE
# ..                          ...     ...                          ...     ...
# 15  ChIJD42B1MD5ei4RB8oVP3WuPCU     4.0  ChIJD42B1MD5ei4RB8oVP3WuPCU  GOOGLE
# 16  ChIJq5Xq1A_5ei4Rh00_nFRpzrs     4.8  ChIJq5Xq1A_5ei4Rh00_nFRpzrs  GOOGLE
# 17  ChIJBV0G5WT5ei4R-iQsUsz_sX8     3.8  ChIJBV0G5WT5ei4R-iQsUsz_sX8  GOOGLE
# 18  ChIJjTQK_ED7ei4RzSvoaPLysXU     4.4  ChIJjTQK_ED7ei4RzSvoaPLysXU  GOOGLE
# 19  ChIJ3-pEEFn5ei4RWCWavr18nBA     5.0  ChIJ3-pEEFn5ei4RWCWavr18nBA  GOOGLE
#
#                                  types  user_ratings_total  \
# 0   [point_of_interest, establishment]                  35
# 1   [point_of_interest, establishment]                 102
# 2   [point_of_interest, establishment]                 171
# 3   [point_of_interest, establishment]                  81
# 4   [point_of_interest, establishment]                 112
# ..                                 ...                 ...
# 15  [point_of_interest, establishment]                   1
# 16  [point_of_interest, establishment]                   6
# 17  [point_of_interest, establishment]                   5
# 18  [point_of_interest, establishment]                   5
# 19  [point_of_interest, establishment]                   4
#
#                                              vicinity  \
# 0         368X+9XW, Greso, Trimurti, Kabupaten Bantul
# 1   Jl. Kp. Bendo Mangiran, Bendo, Trimurti, Kabup...
# 2   26QP+WWR, Singgelo, Singgoto, Poncosari, Kabup...
# 3    36GV+2Q2, Ledok, Sidorejo, Kabupaten Kulon Progo
# 4    367M+4V6, Klampok, Brosot, Kabupaten Kulon Progo
# ..                                                ...
# 15  57C9+XRV, Pereng wetan, RT.53, Pereng Wetan, A...
# 16  572C+V3P, Sabrang Lor, Triwidadi, Kabupaten Ba...
# 17  Unnamed Road, Sengon Karang, Argomulyo, Kabupa...
# 18  56MG+PCX, Bantarejo, Banguncipto, Kabupaten Ku...
# 19      57H6+J9F, Ngentak, Argorejo, Kabupaten Bantul
#
#                                             plus_code
# 0                                                 NaN
# 1   {'compound_code': '37C2+PM Trimurti, Bantul Re...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 15                                                NaN
# 16                                                NaN
# 17  {'compound_code': '57XP+XH Argomulyo, Bantul R...
# 18                                                NaN
# 19                                                NaN
#
# [340 rows x 16 columns]

# %%
lapangan_df = lapangan_df.drop_duplicates(subset = 'vicinity')

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.934011099999998, 'lng'...
# 1      OPERATIONAL  {'location': {'lat': -7.928185699999999, 'lng'...
# 2      OPERATIONAL  {'location': {'lat': -7.960124999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.9249978, 'lng': 110.24...
# 4      OPERATIONAL  {'location': {'lat': -7.937201, 'lng': 110.234...
# ..             ...                                                ...
# 15     OPERATIONAL  {'location': {'lat': -7.8275029, 'lng': 110.26...
# 16     OPERATIONAL  {'location': {'lat': -7.847789, 'lng': 110.270...
# 17     OPERATIONAL  {'location': {'lat': -7.800039399999999, 'lng'...
# 18     OPERATIONAL  {'location': {'lat': -7.816321899999999, 'lng'...
# 19     OPERATIONAL  {'location': {'lat': -7.820927, 'lng': 110.260...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                ...                   ...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                   name        opening_hours  \
# 0                   Lapangan Tegalombo   {'open_now': True}
# 1                       Lapangan Bendo   {'open_now': True}
# 2                   Lapangan PONCOSARI   {'open_now': True}
# 3               Sidorejo Village Field   {'open_now': True}
# 4                        Klampok Field   {'open_now': True}
# ..                                 ...                  ...
# 15                  LAPANGAN BOLA VOLI  {'open_now': False}
# 16              Lapangan Voli Sidodadi   {'open_now': True}
# 17                        Ares stadium                  NaN
# 18     Lapangan sepak bola banguncipto                  NaN
# 19  Lapangan Voli Krida Taruna Ngentak                  NaN
#
#                                                photos  \
# 0   [{'height': 2400, 'html_attributions': ['<a hr...
# 1   [{'height': 1840, 'html_attributions': ['<a hr...
# 2   [{'height': 2448, 'html_attributions': ['<a hr...
# 3   [{'height': 1080, 'html_attributions': ['<a hr...
# 4   [{'height': 3120, 'html_attributions': ['<a hr...
# ..                                                ...
# 15  [{'height': 2560, 'html_attributions': ['<a hr...
# 16  [{'height': 3000, 'html_attributions': ['<a hr...
# 17  [{'height': 1280, 'html_attributions': ['<a hr...
# 18  [{'height': 1152, 'html_attributions': ['<a hr...
# 19  [{'height': 3456, 'html_attributions': ['<a hr...
#
#                        place_id  rating                    reference   scope  \
# 0   ChIJWVEQD2X-ei4RNu5orBGMxUU     4.5  ChIJWVEQD2X-ei4RNu5orBGMxUU  GOOGLE
# 1   ChIJIzJXtGP-ei4R_h2NiX8MN50     4.3  ChIJIzJXtGP-ei4R_h2NiX8MN50  GOOGLE
# 2   ChIJWXkJCQf-ei4R9nctc1bI0e8     4.3  ChIJWXkJCQf-ei4R9nctc1bI0e8  GOOGLE
# 3   ChIJgXS1d4f-ei4Rq5ispU3jGdk     4.4  ChIJgXS1d4f-ei4Rq5ispU3jGdk  GOOGLE
# 4   ChIJjxzVaNj9ei4RkUlK2RaW76w     4.2  ChIJjxzVaNj9ei4RkUlK2RaW76w  GOOGLE
# ..                          ...     ...                          ...     ...
# 15  ChIJD42B1MD5ei4RB8oVP3WuPCU     4.0  ChIJD42B1MD5ei4RB8oVP3WuPCU  GOOGLE
# 16  ChIJq5Xq1A_5ei4Rh00_nFRpzrs     4.8  ChIJq5Xq1A_5ei4Rh00_nFRpzrs  GOOGLE
# 17  ChIJBV0G5WT5ei4R-iQsUsz_sX8     3.8  ChIJBV0G5WT5ei4R-iQsUsz_sX8  GOOGLE
# 18  ChIJjTQK_ED7ei4RzSvoaPLysXU     4.4  ChIJjTQK_ED7ei4RzSvoaPLysXU  GOOGLE
# 19  ChIJ3-pEEFn5ei4RWCWavr18nBA     5.0  ChIJ3-pEEFn5ei4RWCWavr18nBA  GOOGLE
#
#                                  types  user_ratings_total  \
# 0   [point_of_interest, establishment]                  35
# 1   [point_of_interest, establishment]                 102
# 2   [point_of_interest, establishment]                 171
# 3   [point_of_interest, establishment]                  81
# 4   [point_of_interest, establishment]                 112
# ..                                 ...                 ...
# 15  [point_of_interest, establishment]                   1
# 16  [point_of_interest, establishment]                   6
# 17  [point_of_interest, establishment]                   5
# 18  [point_of_interest, establishment]                   5
# 19  [point_of_interest, establishment]                   4
#
#                                              vicinity  \
# 0         368X+9XW, Greso, Trimurti, Kabupaten Bantul
# 1   Jl. Kp. Bendo Mangiran, Bendo, Trimurti, Kabup...
# 2   26QP+WWR, Singgelo, Singgoto, Poncosari, Kabup...
# 3    36GV+2Q2, Ledok, Sidorejo, Kabupaten Kulon Progo
# 4    367M+4V6, Klampok, Brosot, Kabupaten Kulon Progo
# ..                                                ...
# 15  57C9+XRV, Pereng wetan, RT.53, Pereng Wetan, A...
# 16  572C+V3P, Sabrang Lor, Triwidadi, Kabupaten Ba...
# 17  Unnamed Road, Sengon Karang, Argomulyo, Kabupa...
# 18  56MG+PCX, Bantarejo, Banguncipto, Kabupaten Ku...
# 19      57H6+J9F, Ngentak, Argorejo, Kabupaten Bantul
#
#                                             plus_code
# 0                                                 NaN
# 1   {'compound_code': '37C2+PM Trimurti, Bantul Re...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 15                                                NaN
# 16                                                NaN
# 17  {'compound_code': '57XP+XH Argomulyo, Bantul R...
# 18                                                NaN
# 19                                                NaN
#
# [268 rows x 16 columns]

# %%
import re
def search_word(text, word, type):
    if (type == "address"):
        words = text.split(sep=', ')  # Split the text into individual words
    elif (type == "name"):
        words = re.split(r"[', ']", text)

    count = 0
    value = False
    # print(words)

    for w in words:
        if w == word:
            count+=1
            value = True  # Word found
    return value, count # Word not found

# %%
lapangan_df.reset_index(drop = True, inplace = True)

# %%
lapangan_df
# Out:
#     business_status                                           geometry  \
# 0       OPERATIONAL  {'location': {'lat': -7.934011099999998, 'lng'...
# 1       OPERATIONAL  {'location': {'lat': -7.928185699999999, 'lng'...
# 2       OPERATIONAL  {'location': {'lat': -7.960124999999999, 'lng'...
# 3       OPERATIONAL  {'location': {'lat': -7.9249978, 'lng': 110.24...
# 4       OPERATIONAL  {'location': {'lat': -7.937201, 'lng': 110.234...
# ..              ...                                                ...
# 263     OPERATIONAL  {'location': {'lat': -7.8275029, 'lng': 110.26...
# 264     OPERATIONAL  {'location': {'lat': -7.847789, 'lng': 110.270...
# 265     OPERATIONAL  {'location': {'lat': -7.800039399999999, 'lng'...
# 266     OPERATIONAL  {'location': {'lat': -7.816321899999999, 'lng'...
# 267     OPERATIONAL  {'location': {'lat': -7.820927, 'lng': 110.260...
#
#                                                   icon icon_background_color  \
# 0    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4    https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                 ...                   ...
# 263  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 264  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 265  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 266  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 267  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                     icon_mask_base_uri  \
# 0    https://maps.gstatic.com/mapfiles/place_api/ic...
# 1    https://maps.gstatic.com/mapfiles/place_api/ic...
# 2    https://maps.gstatic.com/mapfiles/place_api/ic...
# 3    https://maps.gstatic.com/mapfiles/place_api/ic...
# 4    https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                 ...
# 263  https://maps.gstatic.com/mapfiles/place_api/ic...
# 264  https://maps.gstatic.com/mapfiles/place_api/ic...
# 265  https://maps.gstatic.com/mapfiles/place_api/ic...
# 266  https://maps.gstatic.com/mapfiles/place_api/ic...
# 267  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                    name        opening_hours  \
# 0                    Lapangan Tegalombo   {'open_now': True}
# 1                        Lapangan Bendo   {'open_now': True}
# 2                    Lapangan PONCOSARI   {'open_now': True}
# 3                Sidorejo Village Field   {'open_now': True}
# 4                         Klampok Field   {'open_now': True}
# ..                                  ...                  ...
# 263                  LAPANGAN BOLA VOLI  {'open_now': False}
# 264              Lapangan Voli Sidodadi   {'open_now': True}
# 265                        Ares stadium                  NaN
# 266     Lapangan sepak bola banguncipto                  NaN
# 267  Lapangan Voli Krida Taruna Ngentak                  NaN
#
#                                                 photos  \
# 0    [{'height': 2400, 'html_attributions': ['<a hr...
# 1    [{'height': 1840, 'html_attributions': ['<a hr...
# 2    [{'height': 2448, 'html_attributions': ['<a hr...
# 3    [{'height': 1080, 'html_attributions': ['<a hr...
# 4    [{'height': 3120, 'html_attributions': ['<a hr...
# ..                                                 ...
# 263  [{'height': 2560, 'html_attributions': ['<a hr...
# 264  [{'height': 3000, 'html_attributions': ['<a hr...
# 265  [{'height': 1280, 'html_attributions': ['<a hr...
# 266  [{'height': 1152, 'html_attributions': ['<a hr...
# 267  [{'height': 3456, 'html_attributions': ['<a hr...
#
#                         place_id  rating                    reference   scope  \
# 0    ChIJWVEQD2X-ei4RNu5orBGMxUU     4.5  ChIJWVEQD2X-ei4RNu5orBGMxUU  GOOGLE
# 1    ChIJIzJXtGP-ei4R_h2NiX8MN50     4.3  ChIJIzJXtGP-ei4R_h2NiX8MN50  GOOGLE
# 2    ChIJWXkJCQf-ei4R9nctc1bI0e8     4.3  ChIJWXkJCQf-ei4R9nctc1bI0e8  GOOGLE
# 3    ChIJgXS1d4f-ei4Rq5ispU3jGdk     4.4  ChIJgXS1d4f-ei4Rq5ispU3jGdk  GOOGLE
# 4    ChIJjxzVaNj9ei4RkUlK2RaW76w     4.2  ChIJjxzVaNj9ei4RkUlK2RaW76w  GOOGLE
# ..                           ...     ...                          ...     ...
# 263  ChIJD42B1MD5ei4RB8oVP3WuPCU     4.0  ChIJD42B1MD5ei4RB8oVP3WuPCU  GOOGLE
# 264  ChIJq5Xq1A_5ei4Rh00_nFRpzrs     4.8  ChIJq5Xq1A_5ei4Rh00_nFRpzrs  GOOGLE
# 265  ChIJBV0G5WT5ei4R-iQsUsz_sX8     3.8  ChIJBV0G5WT5ei4R-iQsUsz_sX8  GOOGLE
# 266  ChIJjTQK_ED7ei4RzSvoaPLysXU     4.4  ChIJjTQK_ED7ei4RzSvoaPLysXU  GOOGLE
# 267  ChIJ3-pEEFn5ei4RWCWavr18nBA     5.0  ChIJ3-pEEFn5ei4RWCWavr18nBA  GOOGLE
#
#                                   types  user_ratings_total  \
# 0    [point_of_interest, establishment]                  35
# 1    [point_of_interest, establishment]                 102
# 2    [point_of_interest, establishment]                 171
# 3    [point_of_interest, establishment]                  81
# 4    [point_of_interest, establishment]                 112
# ..                                  ...                 ...
# 263  [point_of_interest, establishment]                   1
# 264  [point_of_interest, establishment]                   6
# 265  [point_of_interest, establishment]                   5
# 266  [point_of_interest, establishment]                   5
# 267  [point_of_interest, establishment]                   4
#
#                                               vicinity  \
# 0          368X+9XW, Greso, Trimurti, Kabupaten Bantul
# 1    Jl. Kp. Bendo Mangiran, Bendo, Trimurti, Kabup...
# 2    26QP+WWR, Singgelo, Singgoto, Poncosari, Kabup...
# 3     36GV+2Q2, Ledok, Sidorejo, Kabupaten Kulon Progo
# 4     367M+4V6, Klampok, Brosot, Kabupaten Kulon Progo
# ..                                                 ...
# 263  57C9+XRV, Pereng wetan, RT.53, Pereng Wetan, A...
# 264  572C+V3P, Sabrang Lor, Triwidadi, Kabupaten Ba...
# 265  Unnamed Road, Sengon Karang, Argomulyo, Kabupa...
# 266  56MG+PCX, Bantarejo, Banguncipto, Kabupaten Ku...
# 267      57H6+J9F, Ngentak, Argorejo, Kabupaten Bantul
#
#                                              plus_code
# 0                                                  NaN
# 1    {'compound_code': '37C2+PM Trimurti, Bantul Re...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 263                                                NaN
# 264                                                NaN
# 265  {'compound_code': '57XP+XH Argomulyo, Bantul R...
# 266                                                NaN
# 267                                                NaN
#
# [268 rows x 16 columns]

# %%
lapangan_df.to_csv('Lapangan Bantul.csv', index = False)
