# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install googlemaps
import googlemaps
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
kulonprogo_df = pd.read_csv("Kulonprogo.csv")
kulonprogo_df
# Out:
#      kecamatan  luas_wilayah_(km2)
# 0        Temon             36.2989
# 1        Wates             32.0024
# 2     Panjatan             44.5923
# 3        Galur             32.9123
# 4       Lendah             35.5919
# 5      Sentolo             52.6534
# 6     Pengasih             61.6647
# 7        Kokap             73.7995
# 8    Girimulyo             54.9042
# 9    Nanggulan             39.6067
# 10  Kalibawang             52.9637
# 11   Samigaluh             69.2931

# %% [markdown]
# ### Scraping Lapangan

# %%
kulonprogo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kecamatan           12 non-null     object
#  1   luas_wilayah_(km2)  12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 324.0+ bytes

# %%
# kulonprogo_df['luas_wilayah_(km2)'] = kulonprogo_df['luas_wilayah_(km2)'].apply(lambda x: float(x.replace(',', '.')))

# %%
def radius(luas):
    return np.sqrt((luas*1000000/np.pi))

# %%
map_client = googlemaps.Client("AIzaSyD4NxoIzL7sZcUB-ZMrGXerlzedHm1YcZA")

# %%
location = pd.DataFrame()

# %%
def place_location(df, nama_kecamatan, nama_kabupaten):
    location_name = f"{nama_kecamatan} {nama_kabupaten}"
    response = map_client.places(query = location_name)
    results = response.get('results')
    if results:
      print(results[0]['geometry']['location'])
      df = df.append(results[0]['geometry']['location'], ignore_index = True)
    else:
      print("No results found for query: ", location_name)

    return df

# %%
for index, row in kulonprogo_df.iterrows():
    location = place_location(location, row['kecamatan'], 'Kabupaten Kulonprogo Yogyakarta')
# Out:
# {'lat': -7.8867789, 'lng': 110.0748749}
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.893727999999999, 'lng': 110.1434668}
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.9063609, 'lng': 110.1711428}
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\2146031030.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# ...

# %%
kulonprogo_df["lat"] = location["lat"]
kulonprogo_df["lng"] = location["lng"]

# %%
place_list = pd.DataFrame()

# %%
def search_places (location, search_string, distance, place_list):
    response = map_client.places_nearby(
        location = location,
        keyword = search_string,
        radius = distance,
    )
    results = response.get('results')
    place_list = place_list.append(results)

    return place_list

# %%
lapangan_df = pd.DataFrame()

# %%
for index, row in kulonprogo_df.iterrows() :
    loc = (location.iloc[index]['lat'], location.iloc[index]['lng'])
    dist = radius(kulonprogo_df.iloc[index]['luas_wilayah_(km2)'])
    location_name = f"{kulonprogo_df.iloc[index]['kecamatan']} Kabupaten Kulonprogo Yogyakarta"
    lapangan_df = search_places(loc, "Lapangan", dist, lapangan_df)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# C:\Users\USER\AppData\Local\Temp\ipykernel_2440\30034148.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# ...

# %% [markdown]
# ### Hasil Scraping Lapangan

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.8968851, 'lng': 110.10...
# 1      OPERATIONAL  {'location': {'lat': -7.875651400000001, 'lng'...
# 2      OPERATIONAL  {'location': {'lat': -7.857836999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.887828, 'lng': 110.104...
# 4      OPERATIONAL  {'location': {'lat': -7.8791527, 'lng': 110.07...
# ..             ...                                                ...
# 15     OPERATIONAL  {'location': {'lat': -7.702015999999999, 'lng'...
# 16     OPERATIONAL  {'location': {'lat': -7.661847899999999, 'lng'...
# 17     OPERATIONAL  {'location': {'lat': -7.6805699, 'lng': 110.11...
# 18     OPERATIONAL  {'location': {'lat': -7.701298, 'lng': 110.090...
# 19     OPERATIONAL  {'location': {'lat': -7.684230299999999, 'lng'...
#
#                                                  icon icon_background_color  \
# ...

# %%
lapangan_df = lapangan_df.drop_duplicates(subset = 'vicinity')

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.8968851, 'lng': 110.10...
# 1      OPERATIONAL  {'location': {'lat': -7.875651400000001, 'lng'...
# 2      OPERATIONAL  {'location': {'lat': -7.857836999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.887828, 'lng': 110.104...
# 4      OPERATIONAL  {'location': {'lat': -7.8791527, 'lng': 110.07...
# ..             ...                                                ...
# 15     OPERATIONAL  {'location': {'lat': -7.702015999999999, 'lng'...
# 16     OPERATIONAL  {'location': {'lat': -7.661847899999999, 'lng'...
# 17     OPERATIONAL  {'location': {'lat': -7.6805699, 'lng': 110.11...
# 18     OPERATIONAL  {'location': {'lat': -7.701298, 'lng': 110.090...
# 19     OPERATIONAL  {'location': {'lat': -7.684230299999999, 'lng'...
#
#                                                  icon icon_background_color  \
# ...

# %%
import re
def search_word(text, word, type):
    if (type == "address"):
        words = text.split(sep=', ')  # Split the text into individual words
    elif (type == "name"):
        words = re.split(r"[', ']", text)

    count = 0
    value = False
    # print(words)

    for w in words:
        if w == word:
            count+=1
            value = True  # Word found
    return value, count # Word not found

# %%
lapangan_df.reset_index(drop = True, inplace = True)

# %%
lapangan_df
# Out:
#     business_status                                           geometry  \
# 0       OPERATIONAL  {'location': {'lat': -7.8968851, 'lng': 110.10...
# 1       OPERATIONAL  {'location': {'lat': -7.875651400000001, 'lng'...
# 2       OPERATIONAL  {'location': {'lat': -7.857836999999999, 'lng'...
# 3       OPERATIONAL  {'location': {'lat': -7.887828, 'lng': 110.104...
# 4       OPERATIONAL  {'location': {'lat': -7.8791527, 'lng': 110.07...
# ..              ...                                                ...
# 186     OPERATIONAL  {'location': {'lat': -7.702015999999999, 'lng'...
# 187     OPERATIONAL  {'location': {'lat': -7.661847899999999, 'lng'...
# 188     OPERATIONAL  {'location': {'lat': -7.6805699, 'lng': 110.11...
# 189     OPERATIONAL  {'location': {'lat': -7.701298, 'lng': 110.090...
# 190     OPERATIONAL  {'location': {'lat': -7.684230299999999, 'lng'...
#
#                                                   icon icon_background_color  \
# ...

# %%
lapangan_df.to_csv('Lapangan Kulonprogo.csv', index = False)
