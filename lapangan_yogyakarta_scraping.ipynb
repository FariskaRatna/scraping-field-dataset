# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install googlemaps
import googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from googlemaps) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2023.7.22)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40711 sha256=44c9aa73f0ac10679e748ed088d0e6e213b00462a2276a2f701256c14b83df05
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
jogja_df = pd.read_csv("Yogyakarta.csv")
jogja_df
# Out:
#        kecamatan luas_wilayah_(km2)
# 0    Mantrijeron               2,61
# 1         Kraton               1,40
# 2     Mergangsan               2,31
# 3     Umbulharjo               8,12
# 4       Kotagede               3,07
# 5   Gondokusuman               3,97
# 6      Danurejan               1,10
# 7     Pakualaman               0,63
# 8     Gondomanan               1,12
# 9      Ngampilan               0,82
# 10    Wirobrajan               1,76
# 11  Gedongtengen               0,96
# 12         Jetis               1,72
# 13     Tegalrejo               2,91

# %% [markdown]
# ### Scraping Lapangan

# %%
jogja_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   kecamatan           14 non-null     object
#  1   luas_wilayah_(km2)  14 non-null     object
# dtypes: object(2)
# memory usage: 352.0+ bytes

# %%
jogja_df['luas_wilayah_(km2)'] = jogja_df['luas_wilayah_(km2)'].apply(lambda x: float(x.replace(',', '.')))

# %%
def radius(luas):
    return np.sqrt((luas*1000000/np.pi))

# %%
map_client = googlemaps.Client("AIzaSyD4NxoIzL7sZcUB-ZMrGXerlzedHm1YcZA")

# %%
location = pd.DataFrame()

# %%
def place_location(df, nama_kecamatan, nama_kabupaten):
    location_name = f"{nama_kecamatan} {nama_kabupaten}"
    response = map_client.places(query = location_name)
    results = response.get('results')
    if results:
      print(results[0]['geometry']['location'])
      df = df.append(results[0]['geometry']['location'], ignore_index = True)
    else:
      print("No results found for query: ", location_name)

    return df

# %%
for index, row in jogja_df.iterrows():
    location = place_location(location, row['kecamatan'], 'Kota Yogyakarta')
# Out:
# {'lat': -7.8196179, 'lng': 110.3576912}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8090256, 'lng': 110.363649}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.815317899999999, 'lng': 110.3731766}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.816772, 'lng': 110.3838939}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8205288, 'lng': 110.4009845}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.783066700000001, 'lng': 110.3792252}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.7932901, 'lng': 110.3696069}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.799499, 'lng': 110.3740754}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.799796400000001, 'lng': 110.3681175}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.797669399999999, 'lng': 110.3591807}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.8032616, 'lng': 110.350244}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.7923751, 'lng': 110.3621596}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.783296999999998, 'lng': 110.363649}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)
# {'lat': -7.7764921, 'lng': 110.3611261}
# <ipython-input-9-684a544e9e9a>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(results[0]['geometry']['location'], ignore_index = True)

# %%
jogja_df["lat"] = location["lat"]
jogja_df["lng"] = location["lng"]

# %%
place_list = pd.DataFrame()

# %%
def search_places (location, search_string, distance, place_list):
    response = map_client.places_nearby(
        location = location,
        keyword = search_string,
        radius = distance,
    )
    results = response.get('results')
    place_list = place_list.append(results)

    return place_list

# %%
lapangan_df = pd.DataFrame()

# %%
for index, row in jogja_df.iterrows() :
    loc = (location.iloc[index]['lat'], location.iloc[index]['lng'])
    dist = radius(jogja_df.iloc[index]['luas_wilayah_(km2)'])
    location_name = f"{jogja_df.iloc[index]['kecamatan']} Kota Yogyakarta"
    lapangan_df = search_places(loc, "Lapangan", dist, lapangan_df)
# Out:
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)
# <ipython-input-13-4cde425eb2a8>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_list = place_list.append(results)

# %% [markdown]
# ### Hasil Scraping Lapangan

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.819417799999999, 'lng'...
# 1      OPERATIONAL  {'location': {'lat': -7.8243923, 'lng': 110.36...
# 2      OPERATIONAL  {'location': {'lat': -7.820259999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.810584400000001, 'lng'...
# 4      OPERATIONAL  {'location': {'lat': -7.813680499999999, 'lng'...
# ..             ...                                                ...
# 9      OPERATIONAL  {'location': {'lat': -7.766764500000001, 'lng'...
# 10     OPERATIONAL  {'location': {'lat': -7.7657762, 'lng': 110.36...
# 11     OPERATIONAL  {'location': {'lat': -7.7789073, 'lng': 110.35...
# 12     OPERATIONAL  {'location': {'lat': -7.7846478, 'lng': 110.35...
# 13     OPERATIONAL  {'location': {'lat': -7.767539999999999, 'lng'...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                ...                   ...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          name        opening_hours  \
# 0                             Minggiran Field   {'open_now': True}
# 1              Lapangan PP Ali Maksum Krapyak                  NaN
# 2            Lapangan Kasunaran ꧋ꦭꦥꦔꦤ꧀ꦏꦱꦸꦤꦫꦤ꧀                  NaN
# 3            Lapangan Kali Winongo Sindurejan                  NaN
# 4   Lapangan Mardawa Mandala(꧋ꦭꦥꦔꦤ꧀ꦩꦂꦣꦮꦩꦤ꧀ꦝꦭ)                  NaN
# ..                                        ...                  ...
# 9      Lapangan Basket Outdoor SMP Budi Utama  {'open_now': False}
# 10                   LAPANGAN VOLLEY SORPUKAT                  NaN
# 11        Lapangan Olahraga SD N Bangunrejo 1  {'open_now': False}
# 12                     GOR Badminton Tompeyan                  NaN
# 13                    Lapangan Tenis Sinduadi   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2340, 'html_attributions': ['<a hr...
# 1   [{'height': 2184, 'html_attributions': ['<a hr...
# 2   [{'height': 4160, 'html_attributions': ['<a hr...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 9   [{'height': 4000, 'html_attributions': ['<a hr...
# 10                                                NaN
# 11  [{'height': 2608, 'html_attributions': ['<a hr...
# 12  [{'height': 3120, 'html_attributions': ['<a hr...
# 13  [{'height': 3468, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo
# ..                          ...
# 9   ChIJi-I9ULZZei4R5H4sa6dcD50
# 10  ChIJMx1Sg_tZei4R65ivK9p2o94
# 11  ChIJM4S_1BlZei4ReeEuwEDSQ4M
# 12  ChIJfWVzfj1Yei4RzXyGKddY9pw
# 13  ChIJE-R5gU9Yei4RXds5_ECHpx0
#
#                                             plus_code  rating  \
# 0   {'compound_code': '59J6+69 Suryodiningratan, Y...     4.4
# 1   {'compound_code': '59G6+6G Mantrijeron, Yogyak...     4.8
# 2                                                 NaN     4.3
# 3                                                 NaN     2.0
# 4                                                 NaN     0.0
# ..                                                ...     ...
# 9   {'compound_code': '69M7+7M Sinduadi, Sleman Re...     4.0
# 10  {'compound_code': '69M8+MX Sinduadi, Sleman Re...     5.0
# 11                                                NaN     5.0
# 12  {'compound_code': '6983+4W Tegalrejo, Yogyakar...     4.5
# 13                                                NaN     4.5
#
#                       reference   scope  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA  GOOGLE
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ  GOOGLE
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI  GOOGLE
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg  GOOGLE
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo  GOOGLE
# ..                          ...     ...
# 9   ChIJi-I9ULZZei4R5H4sa6dcD50  GOOGLE
# 10  ChIJMx1Sg_tZei4R65ivK9p2o94  GOOGLE
# 11  ChIJM4S_1BlZei4ReeEuwEDSQ4M  GOOGLE
# 12  ChIJfWVzfj1Yei4RzXyGKddY9pw  GOOGLE
# 13  ChIJE-R5gU9Yei4RXds5_ECHpx0  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0                  [point_of_interest, establishment]                1749
# 1                  [point_of_interest, establishment]                  30
# 2                  [point_of_interest, establishment]                   4
# 3                  [point_of_interest, establishment]                   1
# 4                  [point_of_interest, establishment]                   0
# ..                                                ...                 ...
# 9                  [point_of_interest, establishment]                   2
# 10                 [point_of_interest, establishment]                   3
# 11  [primary_school, school, point_of_interest, es...                   7
# 12                 [point_of_interest, establishment]                  79
# 13                 [point_of_interest, establishment]                  40
#
#                                              vicinity
# 0   Suryodiningratan, Mantrijeron, Jl. Minggiran B...
# 1   Jl. Jogokaryan No.12 B, Mantrijeron, Kota Yogy...
# 2               59H3+V4W, Gedongkiwo, Yogyakarta City
# 3            59Q2+QJ8, Patangpuluhan, Yogyakarta City
# 4    58PX+GRC, Jomegatan, Ngestiharjo, Bantul Regency
# ..                                                ...
# 9   Magelang St No.4,4, Kutu Dukuh, Sinduadi, Slem...
# 10  Jl. Pocung No.140, Kutu Dukuh, Sinduadi, Kabup...
# 11                  69C5+C4G, Kricak, Yogyakarta City
# 12    Jl. Tompeyan No.161, Tegalrejo, Kota Yogyakarta
# 13   69J8+XQW, Kutu Dukuh, Sinduadi, Kabupaten Sleman
#
# [121 rows x 16 columns]

# %%
lapangan_df = lapangan_df.drop_duplicates(subset = 'vicinity')

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.819417799999999, 'lng'...
# 1      OPERATIONAL  {'location': {'lat': -7.8243923, 'lng': 110.36...
# 2      OPERATIONAL  {'location': {'lat': -7.820259999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.810584400000001, 'lng'...
# 4      OPERATIONAL  {'location': {'lat': -7.813680499999999, 'lng'...
# ..             ...                                                ...
# 8      OPERATIONAL  {'location': {'lat': -7.776131599999999, 'lng'...
# 9      OPERATIONAL  {'location': {'lat': -7.766764500000001, 'lng'...
# 10     OPERATIONAL  {'location': {'lat': -7.7657762, 'lng': 110.36...
# 12     OPERATIONAL  {'location': {'lat': -7.7846478, 'lng': 110.35...
# 13     OPERATIONAL  {'location': {'lat': -7.767539999999999, 'lng'...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                ...                   ...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          name        opening_hours  \
# 0                             Minggiran Field   {'open_now': True}
# 1              Lapangan PP Ali Maksum Krapyak                  NaN
# 2            Lapangan Kasunaran ꧋ꦭꦥꦔꦤ꧀ꦏꦱꦸꦤꦫꦤ꧀                  NaN
# 3            Lapangan Kali Winongo Sindurejan                  NaN
# 4   Lapangan Mardawa Mandala(꧋ꦭꦥꦔꦤ꧀ꦩꦂꦣꦮꦩꦤ꧀ꦝꦭ)                  NaN
# ..                                        ...                  ...
# 8                                   Gor Bener  {'open_now': False}
# 9      Lapangan Basket Outdoor SMP Budi Utama  {'open_now': False}
# 10                   LAPANGAN VOLLEY SORPUKAT                  NaN
# 12                     GOR Badminton Tompeyan                  NaN
# 13                    Lapangan Tenis Sinduadi   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2340, 'html_attributions': ['<a hr...
# 1   [{'height': 2184, 'html_attributions': ['<a hr...
# 2   [{'height': 4160, 'html_attributions': ['<a hr...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 8   [{'height': 4032, 'html_attributions': ['<a hr...
# 9   [{'height': 4000, 'html_attributions': ['<a hr...
# 10                                                NaN
# 12  [{'height': 3120, 'html_attributions': ['<a hr...
# 13  [{'height': 3468, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo
# ..                          ...
# 8   ChIJ81xBLRVYei4ROqttP1YEiPg
# 9   ChIJi-I9ULZZei4R5H4sa6dcD50
# 10  ChIJMx1Sg_tZei4R65ivK9p2o94
# 12  ChIJfWVzfj1Yei4RzXyGKddY9pw
# 13  ChIJE-R5gU9Yei4RXds5_ECHpx0
#
#                                             plus_code  rating  \
# 0   {'compound_code': '59J6+69 Suryodiningratan, Y...     4.4
# 1   {'compound_code': '59G6+6G Mantrijeron, Yogyak...     4.8
# 2                                                 NaN     4.3
# 3                                                 NaN     2.0
# 4                                                 NaN     0.0
# ..                                                ...     ...
# 8                                                 NaN     4.4
# 9   {'compound_code': '69M7+7M Sinduadi, Sleman Re...     4.0
# 10  {'compound_code': '69M8+MX Sinduadi, Sleman Re...     5.0
# 12  {'compound_code': '6983+4W Tegalrejo, Yogyakar...     4.5
# 13                                                NaN     4.5
#
#                       reference   scope                               types  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA  GOOGLE  [point_of_interest, establishment]
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ  GOOGLE  [point_of_interest, establishment]
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI  GOOGLE  [point_of_interest, establishment]
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg  GOOGLE  [point_of_interest, establishment]
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo  GOOGLE  [point_of_interest, establishment]
# ..                          ...     ...                                 ...
# 8   ChIJ81xBLRVYei4ROqttP1YEiPg  GOOGLE  [point_of_interest, establishment]
# 9   ChIJi-I9ULZZei4R5H4sa6dcD50  GOOGLE  [point_of_interest, establishment]
# 10  ChIJMx1Sg_tZei4R65ivK9p2o94  GOOGLE  [point_of_interest, establishment]
# 12  ChIJfWVzfj1Yei4RzXyGKddY9pw  GOOGLE  [point_of_interest, establishment]
# 13  ChIJE-R5gU9Yei4RXds5_ECHpx0  GOOGLE  [point_of_interest, establishment]
#
#     user_ratings_total                                           vicinity
# 0                 1749  Suryodiningratan, Mantrijeron, Jl. Minggiran B...
# 1                   30  Jl. Jogokaryan No.12 B, Mantrijeron, Kota Yogy...
# 2                    4              59H3+V4W, Gedongkiwo, Yogyakarta City
# 3                    1           59Q2+QJ8, Patangpuluhan, Yogyakarta City
# 4                    0   58PX+GRC, Jomegatan, Ngestiharjo, Bantul Regency
# ..                 ...                                                ...
# 8                   61        69F2+GX6, Jl. Bener, Bener, Kota Yogyakarta
# 9                    2  Magelang St No.4,4, Kutu Dukuh, Sinduadi, Slem...
# 10                   3  Jl. Pocung No.140, Kutu Dukuh, Sinduadi, Kabup...
# 12                  79    Jl. Tompeyan No.161, Tegalrejo, Kota Yogyakarta
# 13                  40   69J8+XQW, Kutu Dukuh, Sinduadi, Kabupaten Sleman
#
# [80 rows x 16 columns]

# %%
import re
def search_word(text, word, type):
    if (type == "address"):
        words = text.split(sep=', ')  # Split the text into individual words
    elif (type == "name"):
        words = re.split(r"[', ']", text)

    count = 0
    value = False
    # print(words)

    for w in words:
        if w == word:
            count+=1
            value = True  # Word found
    return value, count # Word not found

# %%
lapangan_df.reset_index(drop = True, inplace = True)

# %%
lapangan_df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': -7.819417799999999, 'lng'...
# 1      OPERATIONAL  {'location': {'lat': -7.8243923, 'lng': 110.36...
# 2      OPERATIONAL  {'location': {'lat': -7.820259999999999, 'lng'...
# 3      OPERATIONAL  {'location': {'lat': -7.810584400000001, 'lng'...
# 4      OPERATIONAL  {'location': {'lat': -7.813680499999999, 'lng'...
# ..             ...                                                ...
# 75     OPERATIONAL  {'location': {'lat': -7.776131599999999, 'lng'...
# 76     OPERATIONAL  {'location': {'lat': -7.766764500000001, 'lng'...
# 77     OPERATIONAL  {'location': {'lat': -7.7657762, 'lng': 110.36...
# 78     OPERATIONAL  {'location': {'lat': -7.7846478, 'lng': 110.35...
# 79     OPERATIONAL  {'location': {'lat': -7.767539999999999, 'lng'...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# ..                                                ...                   ...
# 75  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 76  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 77  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 78  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 79  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# ..                                                ...
# 75  https://maps.gstatic.com/mapfiles/place_api/ic...
# 76  https://maps.gstatic.com/mapfiles/place_api/ic...
# 77  https://maps.gstatic.com/mapfiles/place_api/ic...
# 78  https://maps.gstatic.com/mapfiles/place_api/ic...
# 79  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          name        opening_hours  \
# 0                             Minggiran Field   {'open_now': True}
# 1              Lapangan PP Ali Maksum Krapyak                  NaN
# 2            Lapangan Kasunaran ꧋ꦭꦥꦔꦤ꧀ꦏꦱꦸꦤꦫꦤ꧀                  NaN
# 3            Lapangan Kali Winongo Sindurejan                  NaN
# 4   Lapangan Mardawa Mandala(꧋ꦭꦥꦔꦤ꧀ꦩꦂꦣꦮꦩꦤ꧀ꦝꦭ)                  NaN
# ..                                        ...                  ...
# 75                                  Gor Bener  {'open_now': False}
# 76     Lapangan Basket Outdoor SMP Budi Utama  {'open_now': False}
# 77                   LAPANGAN VOLLEY SORPUKAT                  NaN
# 78                     GOR Badminton Tompeyan                  NaN
# 79                    Lapangan Tenis Sinduadi   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 2340, 'html_attributions': ['<a hr...
# 1   [{'height': 2184, 'html_attributions': ['<a hr...
# 2   [{'height': 4160, 'html_attributions': ['<a hr...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 75  [{'height': 4032, 'html_attributions': ['<a hr...
# 76  [{'height': 4000, 'html_attributions': ['<a hr...
# 77                                                NaN
# 78  [{'height': 3120, 'html_attributions': ['<a hr...
# 79  [{'height': 3468, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo
# ..                          ...
# 75  ChIJ81xBLRVYei4ROqttP1YEiPg
# 76  ChIJi-I9ULZZei4R5H4sa6dcD50
# 77  ChIJMx1Sg_tZei4R65ivK9p2o94
# 78  ChIJfWVzfj1Yei4RzXyGKddY9pw
# 79  ChIJE-R5gU9Yei4RXds5_ECHpx0
#
#                                             plus_code  rating  \
# 0   {'compound_code': '59J6+69 Suryodiningratan, Y...     4.4
# 1   {'compound_code': '59G6+6G Mantrijeron, Yogyak...     4.8
# 2                                                 NaN     4.3
# 3                                                 NaN     2.0
# 4                                                 NaN     0.0
# ..                                                ...     ...
# 75                                                NaN     4.4
# 76  {'compound_code': '69M7+7M Sinduadi, Sleman Re...     4.0
# 77  {'compound_code': '69M8+MX Sinduadi, Sleman Re...     5.0
# 78  {'compound_code': '6983+4W Tegalrejo, Yogyakar...     4.5
# 79                                                NaN     4.5
#
#                       reference   scope                               types  \
# 0   ChIJS-ktK7xXei4ROrQBSWZO4fA  GOOGLE  [point_of_interest, establishment]
# 1   ChIJ6aojzrtXei4Rz2Y8r8wfLpQ  GOOGLE  [point_of_interest, establishment]
# 2   ChIJu-xd8cBXei4RR-KHFlFmmUI  GOOGLE  [point_of_interest, establishment]
# 3   ChIJSVs2x7BXei4RuvhLNJjCNxg  GOOGLE  [point_of_interest, establishment]
# 4   ChIJw3qnCKVXei4RvWNnXddLDFo  GOOGLE  [point_of_interest, establishment]
# ..                          ...     ...                                 ...
# 75  ChIJ81xBLRVYei4ROqttP1YEiPg  GOOGLE  [point_of_interest, establishment]
# 76  ChIJi-I9ULZZei4R5H4sa6dcD50  GOOGLE  [point_of_interest, establishment]
# 77  ChIJMx1Sg_tZei4R65ivK9p2o94  GOOGLE  [point_of_interest, establishment]
# 78  ChIJfWVzfj1Yei4RzXyGKddY9pw  GOOGLE  [point_of_interest, establishment]
# 79  ChIJE-R5gU9Yei4RXds5_ECHpx0  GOOGLE  [point_of_interest, establishment]
#
#     user_ratings_total                                           vicinity
# 0                 1749  Suryodiningratan, Mantrijeron, Jl. Minggiran B...
# 1                   30  Jl. Jogokaryan No.12 B, Mantrijeron, Kota Yogy...
# 2                    4              59H3+V4W, Gedongkiwo, Yogyakarta City
# 3                    1           59Q2+QJ8, Patangpuluhan, Yogyakarta City
# 4                    0   58PX+GRC, Jomegatan, Ngestiharjo, Bantul Regency
# ..                 ...                                                ...
# 75                  61        69F2+GX6, Jl. Bener, Bener, Kota Yogyakarta
# 76                   2  Magelang St No.4,4, Kutu Dukuh, Sinduadi, Slem...
# 77                   3  Jl. Pocung No.140, Kutu Dukuh, Sinduadi, Kabup...
# 78                  79    Jl. Tompeyan No.161, Tegalrejo, Kota Yogyakarta
# 79                  40   69J8+XQW, Kutu Dukuh, Sinduadi, Kabupaten Sleman
#
# [80 rows x 16 columns]

# %%
lapangan_df.to_csv('Lapangan Yogyakarta.csv', index = False)
